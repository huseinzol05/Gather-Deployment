# %%
import luigi
import luigi.contrib.hadoop
import luigi.contrib.hdfs
import json
import numpy as np
import time
# Out:
# Loading GCP module without the python packages httplib2, google-auth.         This *could* crash at runtime if no other credentials are provided.
# Loading GCS module without the python packages googleapiclient & google-auth.         This will crash at runtime if GCS functionality is used.
# Loading S3 module without the python package boto3. Will crash at runtime if S3 functionality is used.

# %%
class Split_text(luigi.Task):
    filename = luigi.Parameter()
    split_size = luigi.IntParameter(default = 5)
    
    def output(self):
        return [luigi.contrib.hdfs.target.HdfsTarget('/user/input_text/text-%d.txt' % (i)) for i in range(self.split_size)]
    
    def run(self):
        with open(self.filename) as fopen:
            texts = list(filter(None, fopen.read().split('\n')))
        splitted_list = np.array_split(texts, self.split_size)
        for i in range(len(splitted_list)):
            splitted_list[i] = splitted_list[i].tolist()
        for no, file in enumerate(self.output()):
            with file.open('w') as fopen:
                fopen.write('\n'.join(splitted_list[no]))

class WordCount_Hadoop(luigi.contrib.hadoop.JobTask):
    filename = luigi.Parameter()
    split_size = luigi.IntParameter(default = 5)

    def requires(self):
        return Split_text(filename = self.filename, split_size = self.split_size)

    def output(self):
        return luigi.contrib.hdfs.target.HdfsTarget('/user/input_text/count.txt',format=luigi.contrib.hdfs.PlainDir)

    def mapper(self, line):
        sentences = list(filter(None, line.split('\n')))
        for sentence in sentences:
            for word in sentence.split():
                yield word, 1
                
    def reducer(self, key, values):
        yield key, sum(values)

# %%
if __name__ == '__main__':
    luigi.build([WordCount_Hadoop(filename='big-text.txt',split_size=10)], 
                scheduler_host = 'localhost', scheduler_port = 8082)
# Out:
# DEBUG: Checking if WordCount_Hadoop(filename=big-text.txt, split_size=10) is complete
# DEBUG: Running file existence check: /opt/hadoop/bin/hadoop fs -stat /user/input_text/count.txt
# DEBUG: Checking if Split_text(filename=big-text.txt, split_size=10) is complete
# DEBUG: Running file existence check: /opt/hadoop/bin/hadoop fs -stat /user/input_text/text-0.txt
# DEBUG: Running file existence check: /opt/hadoop/bin/hadoop fs -stat /user/input_text/text-1.txt
# DEBUG: Running file existence check: /opt/hadoop/bin/hadoop fs -stat /user/input_text/text-2.txt
# DEBUG: Running file existence check: /opt/hadoop/bin/hadoop fs -stat /user/input_text/text-3.txt
# DEBUG: Running file existence check: /opt/hadoop/bin/hadoop fs -stat /user/input_text/text-4.txt
# DEBUG: Running file existence check: /opt/hadoop/bin/hadoop fs -stat /user/input_text/text-5.txt
# DEBUG: Running file existence check: /opt/hadoop/bin/hadoop fs -stat /user/input_text/text-6.txt
# DEBUG: Running file existence check: /opt/hadoop/bin/hadoop fs -stat /user/input_text/text-7.txt
# DEBUG: Running file existence check: /opt/hadoop/bin/hadoop fs -stat /user/input_text/text-8.txt
# DEBUG: Running file existence check: /opt/hadoop/bin/hadoop fs -stat /user/input_text/text-9.txt
# INFO: Informed scheduler that task   WordCount_Hadoop_big_text_txt_10_e4ec2d5150   has status   PENDING
# INFO: Informed scheduler that task   Split_text_big_text_txt_10_e4ec2d5150   has status   DONE
# INFO: Done scheduling tasks
# INFO: Running Worker with 1 processes
# DEBUG: Asking scheduler for work...
# DEBUG: Pending tasks: 1
# INFO: [pid 6971] Worker Worker(salt=666215452, workers=1, host=90693de3b7f1, username=root, pid=6971) running   WordCount_Hadoop(filename=big-text.txt, split_size=10)
# DEBUG: Running file existence check: /opt/hadoop/bin/hadoop fs -stat /user/input_text/text-0.txt
# DEBUG: Running file existence check: /opt/hadoop/bin/hadoop fs -stat /user/input_text/text-1.txt
# DEBUG: Running file existence check: /opt/hadoop/bin/hadoop fs -stat /user/input_text/text-2.txt
# DEBUG: Running file existence check: /opt/hadoop/bin/hadoop fs -stat /user/input_text/text-3.txt
# DEBUG: Running file existence check: /opt/hadoop/bin/hadoop fs -stat /user/input_text/text-4.txt
# DEBUG: Running file existence check: /opt/hadoop/bin/hadoop fs -stat /user/input_text/text-5.txt
# DEBUG: Running file existence check: /opt/hadoop/bin/hadoop fs -stat /user/input_text/text-6.txt
# DEBUG: Running file existence check: /opt/hadoop/bin/hadoop fs -stat /user/input_text/text-7.txt
# DEBUG: Running file existence check: /opt/hadoop/bin/hadoop fs -stat /user/input_text/text-8.txt
# DEBUG: Running file existence check: /opt/hadoop/bin/hadoop fs -stat /user/input_text/text-9.txt
# DEBUG: Tmp dir: /tmp/tmpessanv1d
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/retcodes.py -> luigi/retcodes.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/mock.py -> luigi/mock.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/util.py -> luigi/util.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/parameter.py -> luigi/parameter.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/__init__.py -> luigi/__init__.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/scheduler.py -> luigi/scheduler.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/cmdline_parser.py -> luigi/cmdline_parser.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/db_task_history.py -> luigi/db_task_history.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/lock.py -> luigi/lock.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/task_status.py -> luigi/task_status.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/process.py -> luigi/process.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/server.py -> luigi/server.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/cmdline.py -> luigi/cmdline.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/notifications.py -> luigi/notifications.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/task.py -> luigi/task.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/task_history.py -> luigi/task_history.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/__main__.py -> luigi/__main__.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/execution_summary.py -> luigi/execution_summary.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/format.py -> luigi/format.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/rpc.py -> luigi/rpc.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/file.py -> luigi/file.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/six.py -> luigi/six.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/batch_notifier.py -> luigi/batch_notifier.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/date_interval.py -> luigi/date_interval.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/event.py -> luigi/event.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/task_register.py -> luigi/task_register.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/worker.py -> luigi/worker.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/local_target.py -> luigi/local_target.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/target.py -> luigi/target.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/interface.py -> luigi/interface.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/setup_logging.py -> luigi/setup_logging.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/pig.py -> luigi/contrib/pig.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/external_daily_snapshot.py -> luigi/contrib/external_daily_snapshot.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/hive.py -> luigi/contrib/hive.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/__init__.py -> luigi/contrib/__init__.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/sqla.py -> luigi/contrib/sqla.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/hadoop.py -> luigi/contrib/hadoop.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/dataproc.py -> luigi/contrib/dataproc.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/bigquery.py -> luigi/contrib/bigquery.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/redshift.py -> luigi/contrib/redshift.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/simulate.py -> luigi/contrib/simulate.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/mssqldb.py -> luigi/contrib/mssqldb.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/scalding.py -> luigi/contrib/scalding.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/mysqldb.py -> luigi/contrib/mysqldb.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/webhdfs.py -> luigi/contrib/webhdfs.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/rdbms.py -> luigi/contrib/rdbms.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/esindex.py -> luigi/contrib/esindex.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/lsf_runner.py -> luigi/contrib/lsf_runner.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/ssh.py -> luigi/contrib/ssh.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/batch.py -> luigi/contrib/batch.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/sge_runner.py -> luigi/contrib/sge_runner.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/s3.py -> luigi/contrib/s3.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/mrrunner.py -> luigi/contrib/mrrunner.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/hadoop_jar.py -> luigi/contrib/hadoop_jar.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/mongodb.py -> luigi/contrib/mongodb.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/lsf.py -> luigi/contrib/lsf.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/gcs.py -> luigi/contrib/gcs.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/ftp.py -> luigi/contrib/ftp.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/sge.py -> luigi/contrib/sge.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/bigquery_avro.py -> luigi/contrib/bigquery_avro.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/gcp.py -> luigi/contrib/gcp.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/salesforce.py -> luigi/contrib/salesforce.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/pyspark_runner.py -> luigi/contrib/pyspark_runner.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/ecs.py -> luigi/contrib/ecs.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/opener.py -> luigi/contrib/opener.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/docker_runner.py -> luigi/contrib/docker_runner.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/external_program.py -> luigi/contrib/external_program.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/postgres.py -> luigi/contrib/postgres.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/spark.py -> luigi/contrib/spark.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/target.py -> luigi/contrib/target.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/redis_store.py -> luigi/contrib/redis_store.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/sparkey.py -> luigi/contrib/sparkey.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/kubernetes.py -> luigi/contrib/kubernetes.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/hdfs/abstract_client.py -> luigi/contrib/hdfs/abstract_client.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/hdfs/__init__.py -> luigi/contrib/hdfs/__init__.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/hdfs/config.py -> luigi/contrib/hdfs/config.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/hdfs/error.py -> luigi/contrib/hdfs/error.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/hdfs/clients.py -> luigi/contrib/hdfs/clients.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/hdfs/webhdfs_client.py -> luigi/contrib/hdfs/webhdfs_client.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/hdfs/format.py -> luigi/contrib/hdfs/format.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/hdfs/snakebite_client.py -> luigi/contrib/hdfs/snakebite_client.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/hdfs/target.py -> luigi/contrib/hdfs/target.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/contrib/hdfs/hadoopcli_clients.py -> luigi/contrib/hdfs/hadoopcli_clients.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/templates/history.html -> luigi/templates/history.html
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/templates/layout.html -> luigi/templates/layout.html
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/templates/show.html -> luigi/templates/show.html
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/templates/menu.html -> luigi/templates/menu.html
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/templates/recent.html -> luigi/templates/recent.html
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/configuration/__init__.py -> luigi/configuration/__init__.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/configuration/cfg_parser.py -> luigi/configuration/cfg_parser.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/configuration/core.py -> luigi/configuration/core.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/configuration/toml_parser.py -> luigi/configuration/toml_parser.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/configuration/base_parser.py -> luigi/configuration/base_parser.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/static/visualiser/index.html -> luigi/static/visualiser/index.html
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/static/visualiser/test.html -> luigi/static/visualiser/test.html
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/static/visualiser/fonts/fontawesome-webfont.ttf -> luigi/static/visualiser/fonts/fontawesome-webfont.ttf
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/static/visualiser/fonts/glyphicons-halflings-regular.ttf -> luigi/static/visualiser/fonts/glyphicons-halflings-regular.ttf
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/static/visualiser/fonts/glyphicons-halflings-regular.svg -> luigi/static/visualiser/fonts/glyphicons-halflings-regular.svg
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/static/visualiser/fonts/fontawesome-webfont.woff -> luigi/static/visualiser/fonts/fontawesome-webfont.woff
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/static/visualiser/fonts/fontawesome-webfont.woff2 -> luigi/static/visualiser/fonts/fontawesome-webfont.woff2
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/static/visualiser/fonts/glyphicons-halflings-regular.woff -> luigi/static/visualiser/fonts/glyphicons-halflings-regular.woff
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/static/visualiser/fonts/fontawesome-webfont.svg -> luigi/static/visualiser/fonts/fontawesome-webfont.svg
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/static/visualiser/fonts/glyphicons-halflings-regular.eot -> luigi/static/visualiser/fonts/glyphicons-halflings-regular.eot
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/static/visualiser/fonts/fontawesome-webfont.eot -> luigi/static/visualiser/fonts/fontawesome-webfont.eot
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/static/visualiser/css/luigi.css -> luigi/static/visualiser/css/luigi.css
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/static/visualiser/css/font-awesome.min.css -> luigi/static/visualiser/css/font-awesome.min.css
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/static/visualiser/css/tipsy.css -> luigi/static/visualiser/css/tipsy.css
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/static/visualiser/js/graph.js -> luigi/static/visualiser/js/graph.js
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/static/visualiser/js/luigi.js -> luigi/static/visualiser/js/luigi.js
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/static/visualiser/js/tipsy.js -> luigi/static/visualiser/js/tipsy.js
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/static/visualiser/js/visualiserApp.js -> luigi/static/visualiser/js/visualiserApp.js
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/static/visualiser/js/test/graph_test.js -> luigi/static/visualiser/js/test/graph_test.js
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/static/visualiser/lib
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/static/visualiser/lib/datatables/images/sort_desc.png -> luigi/static/visualiser/lib/datatables/images/sort_desc.png
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/static/visualiser/lib/datatables/images/sort_both.png -> luigi/static/visualiser/lib/datatables/images/sort_both.png
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/static/visualiser/lib/datatables/images/sort_asc.png -> luigi/static/visualiser/lib/datatables/images/sort_asc.png
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/static/visualiser/lib/datatables/images/sort_desc_disabled.png -> luigi/static/visualiser/lib/datatables/images/sort_desc_disabled.png
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/static/visualiser/lib/datatables/images/sort_asc_disabled.png -> luigi/static/visualiser/lib/datatables/images/sort_asc_disabled.png
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/static/visualiser/lib/datatables/css/jquery.dataTables.min.css -> luigi/static/visualiser/lib/datatables/css/jquery.dataTables.min.css
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/static/visualiser/lib/datatables/js/jquery.dataTables.min.js -> luigi/static/visualiser/lib/datatables/js/jquery.dataTables.min.js
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/static/visualiser/lib/bootstrap3/css/bootstrap-theme.min.css -> luigi/static/visualiser/lib/bootstrap3/css/bootstrap-theme.min.css
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/static/visualiser/lib/bootstrap3/css/bootstrap.min.css -> luigi/static/visualiser/lib/bootstrap3/css/bootstrap.min.css
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/static/visualiser/lib/bootstrap3/js/bootstrap.min.js -> luigi/static/visualiser/lib/bootstrap3/js/bootstrap.min.js
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/static/visualiser/lib/d3/dagre-d3.min.js -> luigi/static/visualiser/lib/d3/dagre-d3.min.js
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/static/visualiser/lib/d3/d3.min.js -> luigi/static/visualiser/lib/d3/d3.min.js
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/static/visualiser/lib/URI/1.18.2/URI.js -> luigi/static/visualiser/lib/URI/1.18.2/URI.js
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/tools/__init__.py -> luigi/tools/__init__.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/tools/range.py -> luigi/tools/range.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/tools/deps.py -> luigi/tools/deps.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/tools/luigi_grep.py -> luigi/tools/luigi_grep.py
# DEBUG: adding to tar: /usr/local/lib/python3.5/dist-packages/luigi/tools/deps_tree.py -> luigi/tools/deps_tree.py
# ERROR: [pid 6971] Worker Worker(salt=666215452, workers=1, host=90693de3b7f1, username=root, pid=6971) failed    WordCount_Hadoop(filename=big-text.txt, split_size=10)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/luigi/worker.py", line 199, in run
#     new_deps = self._run_get_new_deps()
#   File "/usr/local/lib/python3.5/dist-packages/luigi/worker.py", line 139, in _run_get_new_deps
#     task_gen = self.task.run()
#   File "/usr/local/lib/python3.5/dist-packages/luigi/contrib/hadoop.py", line 740, in run
#     self.job_runner().run_job(self)
#   File "/usr/local/lib/python3.5/dist-packages/luigi/contrib/hadoop.py", line 577, in run_job
#     create_packages_archive(packages, os.path.join(self.tmp_dir, 'packages.tar'))
#   File "/usr/local/lib/python3.5/dist-packages/luigi/contrib/hadoop.py", line 187, in create_packages_archive
#     f = package.__file__
# AttributeError: module '__main__' has no attribute '__file__'
# DEBUG: Removing directory /tmp/tmpessanv1d
# DEBUG: 1 running tasks, waiting for next task to finish
# INFO: Informed scheduler that task   WordCount_Hadoop_big_text_txt_10_e4ec2d5150   has status   FAILED
# DEBUG: Asking scheduler for work...
# DEBUG: Done
# DEBUG: There are no more tasks to run at this time
# DEBUG: There are 1 pending tasks possibly being run by other workers
# DEBUG: There are 1 pending tasks unique to this worker
# DEBUG: There are 1 pending tasks last scheduled by this worker
# INFO: Worker Worker(salt=666215452, workers=1, host=90693de3b7f1, username=root, pid=6971) was stopped. Shutting down Keep-Alive thread
# INFO:
# ===== Luigi Execution Summary =====
#
# Scheduled 2 tasks of which:
# * 1 complete ones were encountered:
#     - 1 Split_text(filename=big-text.txt, split_size=10)
# * 1 failed:
#     - 1 WordCount_Hadoop(filename=big-text.txt, split_size=10)
#
# This progress looks :( because there were failed tasks
#
# ===== Luigi Execution Summary =====
